# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt

data_file1 = 'All_Metro.txt'
data_file2='Population.txt'
metro_df=pd.read_csv(data_file, delim_whitespace=True)
population_df= pd.read_csv(data_file2, delim_whitespace=True)

# %%
metro_df.tail()
# Out:
#       Date  ROTP  RailReliability  MetroAccessOTP  EscalatorAvail  \
# 79  201708  0.89            83133            0.91            0.94
# 80  201709  0.87            83890            0.90            0.95
# 81  201710  0.88            99876            0.93            0.94
# 82  201711  0.87            80687            0.93            0.94
# 83  201712  0.86            85310            0.94            0.94
#
#    ElevatorAvail  TotalInjuries  Crime  Ridership
# 79           97%           2.03    4.8   19645882
# 80           97%           2.61    5.2   18560071
# 81           97%           1.87    4.1   20248022
# 82           97%           1.92    3.9   17932152
# 83           98%           2.15    3.8   15908483

# %%
population_df
# Out:
#    Year  Population
# 0  2012     5603696
# 1  2013     5759330
# 2  2014     5863608
# 3  2015     5949403
# 4  2016     6011752
# 5  2017     6108817

# %%
metro_df.index.name='Index'
metro_df.head()
# Out:
#          Date   ROTP  RailReliability  MetroAccessOTP  EscalatorAvail  \
# Index
# 0      201101  0.879            48241           0.901           0.888
# 1      201102  0.887            37703           0.890           0.866
# 2      201103  0.910            50328           0.913           0.869
# 3      201104  0.909            39302           0.912           0.862
# 4      201105  0.909            37355           0.922           0.825
#
#       ElevatorAvail  TotalInjuries  Crime  Ridership
# Index
# 0            96.30%           2.08   6.39   21082553
# 1            96.00%           1.66   4.68   21228262
# 2            96.90%           2.16   3.96   26170157
# 3            96.40%           2.21   4.72   25656797
# 4            97.40%           1.69   7.32   24342603

# %%
import seaborn as sns
df = metro_df

fig, ax = plt.subplots(figsize=(20,10))
x_limit = 86
x_axis = np.arange(0,x_limit)

plot_index = metro_df.index

sns.regplot(df.index.values, y=df["Ridership"])

# %%
sns.regplot(df.index.values, y=df["Crime"])

# %%
sns.regplot(df.index.values, y=df["RailReliability"])

# %%
sns.regplot(df.index.values, y=df["MetroAccessOTP"])

# %%
sns.regplot(df.index.values, y=df["EscalatorAvail"])

# %%
sns.regplot(df.index.values, y=df["TotalInjuries"])

# %%
sns.regplot(df.index.values, y=df["Crime"])
