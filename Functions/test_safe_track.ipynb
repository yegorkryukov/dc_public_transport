# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from TCSI.Marc_Project_3_Module import TCSI
from Linear_regression_plot import linear_regression_plot
from Linear_regression import linear_regression

# %%
df1 = pd.DataFrame(pd.read_csv('../results/combined.csv'))
df2 = pd.DataFrame(pd.read_csv('../results/metro_kpi.csv'))
df = pd.merge(df1, df2, on='Date', how='outer')
df['ElevatorAvail'] = df['ElevatorAvail'].str.rstrip('%').astype('float')
df['ElevatorAvail'] = df['ElevatorAvail'] /100
df['Date'] = pd.to_datetime(df['Date'])
df.head()
# Out:
#         Date  Bus  Ridership_x  Taxi  Uber  Unnamed: 0   ROTP  \
# 0 2011-01-01  NaN   21082553.0   NaN   NaN         0.0  0.879
# 1 2011-02-01  NaN   21228262.0   NaN   NaN         1.0  0.887
# 2 2011-03-01  NaN   26170157.0   NaN   NaN         2.0  0.910
# 3 2011-04-01  NaN   25656797.0   NaN   NaN         3.0  0.909
# 4 2011-05-01  NaN   24342603.0   NaN   NaN         4.0  0.909
#
#    RailReliability  MetroAccessOTP  EscalatorAvail  ElevatorAvail  \
# 0          48241.0           0.901           0.888          0.963
# 1          37703.0           0.890           0.866          0.960
# 2          50328.0           0.913           0.869          0.969
# 3          39302.0           0.912           0.862          0.964
# 4          37355.0           0.922           0.825          0.974
#
#    TotalInjuries  Crime  Ridership_y
# 0           2.08   6.39   21082553.0
# 1           1.66   4.68   21228262.0
# 2           2.16   3.96   26170157.0
# 3           2.21   4.72   25656797.0
# ...

# %%
df_before = df.loc[df['Date']<'2015-01-01',:]
df_after = df.loc[df['Date']>='2015-01-01',:]

# %%
df_rr_before = df_before[['Ridership_x', 'ROTP', 'RailReliability']]
df_rr_after = df_after[['Ridership_x', 'ROTP', 'RailReliability']]

# %%
linear_regression_plot(df_rr_before, 0)
linear_regression(df_rr_before, 0)
# Out:
# ((0.12420817354214653, 0.05032700203087516, 0.024017172077175356),
#  <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
# ...
#  Dep. Variable:            Ridership_x   R-squared:                       0.124
#  Model:                            OLS   Adj. R-squared:                  0.085
#  Method:                 Least Squares   F-statistic:                     3.191
#  Date:                Tue, 17 Apr 2018   Prob (F-statistic):             0.0506
#  Time:                        18:47:14   Log-Likelihood:                -762.90
#  No. Observations:                  48   AIC:                             1532.
#  Df Residuals:                      45   BIC:                             1537.
#  Df Model:                           2
#  Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
linear_regression_plot(df_rr_after, 0)
linear_regression(df_rr_after, 0)
# Out:
# ((0.1883171462717418, 0.012540323459303332, 0.4824364653210865),
#  <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
# ...
#  Dep. Variable:            Ridership_x   R-squared:                       0.188
#  Model:                            OLS   Adj. R-squared:                  0.139
#  Method:                 Least Squares   F-statistic:                     3.828
#  Date:                Tue, 17 Apr 2018   Prob (F-statistic):             0.0320
#  Time:                        18:47:33   Log-Likelihood:                -573.01
#  No. Observations:                  36   AIC:                             1152.
#  Df Residuals:                      33   BIC:                             1157.
#  Df Model:                           2
#  Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ...
