# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from TCSI.Marc_Project_3_Module_v2 import TCSI
from Linear_regression import linear_regression
from Linear_regression_plot import linear_regression_plot

# %%
df = pd.DataFrame(pd.read_csv('../results/combined.csv'))
df['Date'] = pd.to_datetime(df['Date'])
df.head()
# Out:
#         Date  Bus   Ridership  Taxi  Uber
# 0 2011-01-01  NaN  21082553.0   NaN   NaN
# 1 2011-02-01  NaN  21228262.0   NaN   NaN
# 2 2011-03-01  NaN  26170157.0   NaN   NaN
# 3 2011-04-01  NaN  25656797.0   NaN   NaN
# 4 2011-05-01  NaN  24342603.0   NaN   NaN

# %%
features = [column for column in df]

# %%
x = 0
f, ax = plt.subplots(figsize=(10,5))
for feature in features:
    if feature != 'Date':
        df1 = df[['Date', feature]]
        #pprint(time)
        m, tcsidf = TCSI(df1)
        #print(years[x])
        #print(tcsidf)
        tcsidf.plot(x='Date', y='trend', ax=ax, linewidth=2)
        #ax = tcsidf.plot(x='Date', y='trend')
        plt.title(f'Trend in {feature}')
        x +=1
# Out:
# /Users/sonik/anaconda3/envs/pythondata/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
x = 0
plt.figure()
for feature in features:
    if feature != 'Date':
        df1 = df[['Date', feature]]
        
        m, tcsidf = TCSI(df1)
        
        ax = tcsidf.plot(x='Date', y='trend')
        plt.title(f'Trend in {feature}')
        x +=1

# %%
dfR = df[['Date', 'Ridership']]
m, tcsidf = TCSI(dfR)
dfR1 = tcsidf[['Date', 'trend']]

# %%
linear_regression(dfR1, 1)
linear_regression_plot(dfR1,1)

# %%
linear_regression(dfR1, 1)
# Out:
# ((0.901827127235836, 5.239943909691366e-37),
#  <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:                  trend   R-squared:                       0.902
#  Model:                            OLS   Adj. R-squared:                  0.900
#  Method:                 Least Squares   F-statistic:                     643.0
#  Date:                Thu, 19 Apr 2018   Prob (F-statistic):           5.24e-37
#  Time:                        17:39:45   Log-Likelihood:                -1048.0
#  No. Observations:                  72   AIC:                             2100.
#  Df Residuals:                      70   BIC:                             2105.
#  Df Model:                           1
#  Covariance Type:            nonrobust
#  ==============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
#  ------------------------------------------------------------------------------
#  const        2.45e+07    1.2e+05    203.947      0.000    2.43e+07    2.47e+07
#  Date       -2430.8605     95.862    -25.358      0.000   -2622.051   -2239.670
#  ==============================================================================
#  Omnibus:                        8.131   Durbin-Watson:                   0.033
#  Prob(Omnibus):                  0.017   Jarque-Bera (JB):                5.817
#  Skew:                           0.563   Prob(JB):                       0.0545
#  Kurtosis:                       2.180   Cond. No.                     2.48e+03
#  ==============================================================================
#
#  Warnings:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  [2] The condition number is large, 2.48e+03. This might indicate that there are
#  strong multicollinearity or other numerical problems.
#  """)

# %%
month = 78 # 2017-07-01
-2430.8605 * 78 + 24500000
# Out:
# 24310392.881

# %%
pred_df = dfR1.copy()
